# %%
from sympy import *
from sympy.abc import x,n

# %%
# Evaluate the following integrals using a computer algebra system

# %%
a = Integral(ln(x))
a
# Out:
# Integral(log(x), x)

# %%
b = Integral(ln(x)*x)
b
# Out:
# Integral(x*log(x), x)

# %%
c = Integral(ln(x)*x**2)
c
# Out:
# Integral(x**2*log(x), x)

# %%
d = Integral(ln(x)*x**3)
d
# Out:
# Integral(x**3*log(x), x)

# %%
e = Integral(ln(x)*x**7)
e
# Out:
# Integral(x**7*log(x), x)

# %%
# Solutions to the above equations:

# %%
Eq(a,a.doit())
# Out:
# Eq(Integral(log(x), x), x*log(x) - x)

# %%
Eq(b,b.doit())
# Out:
# Eq(Integral(x*log(x), x), x**2*log(x)/2 - x**2/4)

# %%
Eq(c,c.doit())
# Out:
# Eq(Integral(x**2*log(x), x), x**3*log(x)/3 - x**3/9)

# %%
Eq(d,d.doit())
# Out:
# Eq(Integral(x**3*log(x), x), x**4*log(x)/4 - x**4/16)

# %%
Eq(e,e.doit())
# Out:
# Eq(Integral(x**7*log(x), x), x**8*log(x)/8 - x**8/64)

# %%
# Guess the value of the integral x**n * ln(x)

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
# Use integration by parts to prove this conjecture and what n values are valid?

# %% [markdown]
# ![Screenshot%20from%202022-05-08%2008-25-21.png](attachment:Screenshot%20from%202022-05-08%2008-25-21.png)

# %% [markdown]
# ![22.png](attachment:22.png)
